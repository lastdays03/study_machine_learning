# %% [markdown]
# # Week 4 Final Challenge: 와인 품질 분류 예측
#
# ## 미션
# 사이킷런의 **와인(Wine)** 데이터셋을 사용하여 와인의 종류(Class 0, 1, 2)를 예측하는 모델을 만드세요.
# **로지스틱 회귀**와 **랜덤 포레스트** 모델을 각각 학습시키고 성능을 비교해보세요.

# %% [markdown]
# ### 1. 데이터 로드 및 분리
# `load_wine` 함수를 사용하세요.

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

wine = load_wine()
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.2, random_state=13)

# %% [markdown]
# ### 2. 모델 학습 및 비교
# 두 모델을 학습시키고 정확도(Accuracy)를 출력하세요.

# %%
# Logistic Regression
lr = LogisticRegression(max_iter=10000)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
print(f"Logistic Regression Accuracy: {accuracy_score(y_test, lr_pred):.4f}")

# Random Forest
rf = RandomForestClassifier(random_state=13)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
print(f"Random Forest Accuracy: {accuracy_score(y_test, rf_pred):.4f}")

# %% [markdown]
# ### 3. 상세 리포트
# 성능이 더 좋은 모델의 `classification_report`를 출력하세요.

# %%
print("Random Forest Classification Report:\n")
print(classification_report(y_test, rf_pred, target_names=wine.target_names))

# %% [markdown]
# ## 6. 인사이트 도출 (Insights)
#
# ### 🌟 Key Takeaways
# *   **모델 비교**: 같은 데이터라도 로지스틱 회귀와 랜덤 포레스트 중 누가 더 잘 맞추는지 경쟁시킬 수 있었습니다. (보통은 앙상블인 랜덤 포레스트가 우세합니다.)
# *   **종합적 판단**: 단순히 정확도(Accuracy)뿐만 아니라 F1 Score, ROC/AUC를 종합적으로 고려하여 "좋은 모델"을 선발해야 함을 확인했습니다.
#
# ### 🔬 Try More
# *   **피처 중요도**: 랜덤 포레스트 모델의 `feature_importances_` 속성을 출력해보세요. 와인 품질에 가장 큰 영향을 미치는 성분은 알코올일까요, 아니면 산도일까요?
