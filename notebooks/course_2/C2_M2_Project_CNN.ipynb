# %% [markdown]
# # C2 M2 Project CNN
# **Course**: Course 2 (Master Class)
# **Workflow**: `data-notebook-refiner`
#
# ---

# %%
import torch.nn.functional as F
# 🔧 Setup & Imports
import torch
import torch.nn as nn

# %% [markdown]
# ## 1. 🧠 CNN의 이해
# > **합성곱 신경망(CNN)**은 이미지 처리에 특화된 구조입니다.
# *   **Conv2d**: 이미지의 특징(Edge, Texture)을 추출합니다.
# *   **MaxPool**: 중요 정보는 남기고 크기를 줄입니다.

# %%
# 모델 아키텍처
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 3) # 1채널(흑백) 입력
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 3)
        self.fc1 = nn.Linear(16 * 6 * 6, 120)
        self.fc2 = nn.Linear(120, 10)
    
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

cnn = SimpleCNN()
print(cnn)
# Out:
# SimpleCNN(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=576, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ## 2. 🧪 차원 점검 (Mock Data)
# 가상의 데이터를 통과시켜 입출력 형태(Shape)가 맞는지 확인합니다.

# %%
dummy_img = torch.randn(1, 1, 32, 32)
out = cnn(dummy_img)
print('Input Shape: (1, 1, 32, 32)')
print(f'Output Shape: {out.shape} -> (1, 10) Classification Logits')
# Out:
# Input Shape: (1, 1, 32, 32)
# Output Shape: torch.Size([1, 10]) -> (1, 10) Classification Logits

# %% [markdown]
# ---
# ## 📝 핵심 요약 및 인사이트
# *   **무엇을 배웠나요?**
#     *   (여기에 핵심 배운 점을 기록하세요)
# *   **다음 단계**:
#     *   (다음 학습 단계)
