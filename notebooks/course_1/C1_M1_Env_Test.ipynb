# %% [markdown]
# # 1주차 Session 2: 환경 설정 및 라이브러리 테스트 (Environment Setup)
#
# 이 노트북은 로컬 Python 머신러닝 환경이 정상적으로 구축되었는지 확인하는 용도입니다.
# 필수 라이브러리(`numpy`, `pandas`, `matplotlib`, `scikit-learn` 등)가 잘 설치되었는지, 그리고 Python 버전을 확인합니다.

# %% [markdown]
# ### 1. 시스템 및 Python 버전 확인

# %%
import sys
import platform

print(f"Python Version: {sys.version}")
print(f"Platform: {platform.platform()}")
print("Hello, Machine Learning World!")
# Out:
# Python Version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]
# Platform: macOS-26.2-arm64-arm-64bit-Mach-O
# Hello, Machine Learning World!

# %% [markdown]
# ### 2. 라이브러리 임포트 테스트
# 아래 셀을 실행했을 때 에러가 발생하지 않아야 합니다.

# %%
try:
    import numpy as np
    print(f"Numpy Version: {np.__version__}")
    import pandas as pd
    print(f"Pandas Version: {pd.__version__}")
    import matplotlib
    print(f"Matplotlib Version: {matplotlib.__version__}")
    import sklearn
    print(f"Scikit-learn Version: {sklearn.__version__}")
    print("\nBuild Success! 모든 라이브러리가 정상적으로 설치되었습니다.")
except ImportError as e:
    print(f"\n[Error] 라이브러리 설치가 필요합니다: {e}")
# Out:
# Numpy Version: 2.4.0
# Pandas Version: 2.3.3
# Matplotlib Version: 3.10.8
# Scikit-learn Version: 1.8.0
#
# Build Success! 모든 라이브러리가 정상적으로 설치되었습니다.

# %% [markdown]
# ## 2. 인사이트 도출 (Insights)
#
# ### 🌟 Key Takeaways
# *   **환경의 중요성**: 모든 머신러닝 프로젝트의 시작은 올바른 환경 설정입니다. Python 버전과 라이브러리 버전을 확인함으로써 호환성 문제를 예방할 수 있음을 배웠습니다.
# *   **라이브러리 역할**: `numpy`는 수치 계산, `pandas`는 데이터 조작, `matplotlib`는 시각화를 당담하는 3대장임을 확인했습니다.
#
# ### 🔬 Try More
# *   **라이브러리 버전 변경**: 가상환경에서 `pip install pandas==1.0.0` 처럼 버전을 바꿔보고 코드가 돌아가는지 확인해보세요. (실무에서는 흔한 일입니다!)
