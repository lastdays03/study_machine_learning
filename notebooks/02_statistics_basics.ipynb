# %% [markdown]
# # 1주차 Session 3: 기초 통계와 확률 (Basic Statistics)
#
# Numpy와 Matplotlib을 사용하여 평균, 표준편차, 중앙값 등 기술 통계의 3대장 개념을 실습하고, 정규 분포(Normal Distribution)를 시각화해 봅니다.

# %% [markdown]
# ### 1. 데이터 생성 (Random Generation)
# 평균이 0이고 표준편차가 1인 표준 정규 분포 데이터를 1000개 생성합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성 (평균 0, 표준편차 1인 난수 1000개)
data = np.random.normal(loc=0, scale=1, size=1000)

# %% [markdown]
# ### 2. 기술 통계량 계산
# *   **평균 (Mean)**: 데이터의 무게 중심
# *   **표준편차 (Std)**: 데이터가 퍼져 있는 정도
# *   **중앙값 (Median)**: 순서대로 줄 세웠을 때 딱 중간에 있는 값 (이상치에 영향 적음)

# %%
print(f"평균(Mean): {np.mean(data):.4f}")
print(f"표준편차(Std): {np.std(data):.4f}")
print(f"중앙값(Median): {np.median(data):.4f}")
# Out:
# 평균(Mean): -0.0008
# 표준편차(Std): 1.0163
# 중앙값(Median): -0.0050

# %% [markdown]
# ### 3. 데이터 시각화 (Histogram)
# 데이터의 분포 모양을 히스토그램으로 확인합니다. 종 모양(Bell Curve)이 나오는지 확인해보세요.

# %%
plt.figure(figsize=(8, 5))
plt.hist(data, bins=30, alpha=0.7, color='skyblue', edgecolor='black')
plt.title("Normal Distribution (Mean=0, Std=1)")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 5. 인사이트 도출 (Insights)
#
# ### 🌟 Key Takeaways
# *   **통계의 힘**: 수만 개의 데이터를 `mean`(평균), `std`(표준편차)와 같은 몇 개의 숫자로 요약할 수 있음을 확인했습니다.
# *   **분포의 이해**: 평균만으로는 데이터를 다 설명할 수 없으며, 분산과 표준편차를 통해 데이터가 얼마나 퍼져있는지 알아야 함을 배웠습니다.
#
# ### 🔬 Try More
# *   **중앙값(Median) vs 평균(Mean)**: 데이터 값 중 하나를 아주 큰 값(이상치)으로 바꾸고, 평균과 중앙값이 어떻게 변하는지 비교해보세요. 누가 더 이상치에 강한가요?
