# %% [markdown]
# # 3주차 Session 1: 선형 회귀의 원리 (Practice Questions)
#
# 이 노트북은 `docs/study_notes/Week3_01_Regression_Principles.md`의 내용을 복습하고 개념을 확인하기 위한 질문지입니다.

# %% [markdown]
# ### Q1. 선형 회귀 예측값 계산
# 만약 $H(x) = 2x + 5$ 라는 모델이 있을 때, $x=3$ 이면 예측값은 얼마인가요?

# %% [markdown]
# **[답변]**:
# 11

# %% [markdown]
# ### Q2. 오차(Error) 계산
# 위 질문에서 실제 정답($y$)이 10이라면, 오차(Error = 예측값 - 실제값)는 얼마인가요?

# %% [markdown]
# **[답변]**:
# 1

# %% [markdown]
# ### Q3. 비용 함수(Cost Function)의 의미
# 비용 함수(Cost Function) 값이 크다는 것은 모델의 성능이 좋다는 뜻일까요, 나쁘다는 뜻일까요?

# %% [markdown]
# **[답변]**:
# 비용 함수(Cost Function) 값이 크다는 것은 모델의 성능이 나쁜 뜻입니다.

# %% [markdown]
# ## 4. 인사이트 도출 (Insights)
#
# ### 🌟 Key Takeaways
# *   **선형 회귀의 본질**: 데이터의 경향성을 가장 잘 설명하는 **직선 하나($$ y = wx + b $$)**를 찾는 과정입니다.
# *   **비용 함수(Cost Function)**: 직선이 데이터와 얼마나 틀렸는지 측정하는 기준이며, 이를 최소화하는 것이 학습의 목표임을 배웠습니다.
#
# ### 🔬 Try More
# *   **수동 학습**: $w$와 $b$ 값을 코드로 직접 조금씩 바꿔가며 MSE(오차)가 어떻게 변하는지 그래프로 그려보세요.
